# %%
import matplotlib.pyplot as plt
import numpy as np
x1_adc=[1242,
1100,
984,
856,
734,
610,
490,
368,
232,
110]
y1_ma=[1011,
896,
803,
701,
603,
502,
406,
308,
200,
102]
y2_ma=[510,1012,1508,2011,2490,3048,3513,4086,4497,5012]
x2_adc=[315,624,930,1240,1536,1878,2166,2519,2769,3083]

x3_adc=[224,204,154,104,54,4]
y3_ma_3=[814,749,584,419,255,96]
y3_ma_5=[810,745,581,417,254,95]
x_adc=x3_adc
y_ma=y3_ma_5
plt.plot(x_adc, y_ma, 'ro')
#拟合曲线得到斜率和截距
z1 = np.polyfit(x_adc, y_ma, 1)
p1 = np.poly1d(z1)
print(p1)
plt.plot(x_adc, p1(x_adc), 'b-')
# Out:
#
# 3.257 x + 79.8
